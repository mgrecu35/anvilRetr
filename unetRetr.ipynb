# %%
import uNet1D as unet
import importlib
importlib.reload(unet)
#unet=unet.unet1D(input_size = (48,3))
#print(unet.summary())
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras.layers import Input, concatenate
import tensorflow as tf
nchannels=2
input_tb_size=10
noutputs=48
#noutputs=48,nchannels=1,ndense=32
tbmodel_dense=unet.tbMLP(input_tb_size,noutputs=48,nchannels=2,ndense=32)

lidarModel=unet.unet1D(input_size = (48,1+nchannels),nfilters=8)
print(lidarModel.summary())
print(tbmodel_dense.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 48, 3)]      0           []
#
#  conv1d_24 (Conv1D)             (None, 48, 8)        80          ['input_4[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 48, 8)        200         ['conv1d_24[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 24, 8)       0           ['conv1d_25[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 24, 16)       400         ['max_pooling1d_4[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 24, 16)       784         ['conv1d_26[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 12, 16)      0           ['conv1d_27[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 12, 32)       1568        ['max_pooling1d_5[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 12, 32)       3104        ['conv1d_28[0][0]']
#
#  max_pooling1d_6 (MaxPooling1D)  (None, 6, 32)       0           ['conv1d_29[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 6, 64)        6208        ['max_pooling1d_6[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 6, 64)        12352       ['conv1d_30[0][0]']
#
#  dropout_2 (Dropout)            (None, 6, 64)        0           ['conv1d_31[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 3, 64)       0           ['dropout_2[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 3, 128)       24704       ['max_pooling1d_7[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 3, 128)       49280       ['conv1d_32[0][0]']
#
#  dropout_3 (Dropout)            (None, 3, 128)       0           ['conv1d_33[0][0]']
#
#  up_sampling1d_4 (UpSampling1D)  (None, 6, 128)      0           ['dropout_3[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 6, 64)        16448       ['up_sampling1d_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 6, 128)       0           ['dropout_2[0][0]',
#                                                                   'conv1d_34[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 6, 64)        24640       ['concatenate_4[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 6, 64)        12352       ['conv1d_35[0][0]']
#
#  up_sampling1d_5 (UpSampling1D)  (None, 12, 64)      0           ['conv1d_36[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 12, 32)       4128        ['up_sampling1d_5[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 12, 64)       0           ['conv1d_29[0][0]',
#                                                                   'conv1d_37[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 12, 32)       6176        ['concatenate_5[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 12, 32)       3104        ['conv1d_38[0][0]']
#
#  up_sampling1d_6 (UpSampling1D)  (None, 24, 32)      0           ['conv1d_39[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 24, 16)       1040        ['up_sampling1d_6[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 24, 32)       0           ['conv1d_27[0][0]',
#                                                                   'conv1d_40[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 24, 16)       1552        ['concatenate_6[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 24, 16)       784         ['conv1d_41[0][0]']
#
#  up_sampling1d_7 (UpSampling1D)  (None, 48, 16)      0           ['conv1d_42[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 48, 8)        264         ['up_sampling1d_7[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 48, 16)       0           ['conv1d_25[0][0]',
#                                                                   'conv1d_43[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 48, 8)        392         ['concatenate_7[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 48, 8)        200         ['conv1d_44[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 48, 2)        50          ['conv1d_45[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 48, 1)        3           ['conv1d_46[0][0]']
#
# ==================================================================================================
# Total params: 169,813
# Trainable params: 169,813
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 10)]              0
#
#  dense_3 (Dense)             (None, 32)                352
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 96)                3168
#
#  tf.reshape_1 (TFOpLambda)   (None, 48, 2)             0
#
# =================================================================
# Total params: 4,576
# Trainable params: 4,576
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def active_passive_Unet(input1_size,input_tb_size):
    #define network with two inputs
    input1 = Input(input1_size)
    input2 = Input(input_tb_size)
    #define CNN
    dense_out=tbmodel_dense(input2)
    # concatenate output of CNN with input1
    x = concatenate([input1,dense_out],axis=-1)
    out=lidarModel(x)
    return tf.keras.Model([input1,input2],out)



unetLidarRadiometer=active_passive_Unet(input1_size=(48,1),input_tb_size=10)
print(unetLidarRadiometer.summary())
unetLidarRadiometer.compile(
        optimizer=optimizers.Adam(learning_rate=0.001),
        loss=losses.MeanSquaredError(),
        metrics=['mse'])
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 10)]         0           []
#
#  input_5 (InputLayer)           [(None, 48, 1)]      0           []
#
#  model_2 (Functional)           (None, 48, 2)        4576        ['input_6[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 48, 3)        0           ['input_5[0][0]',
#                                                                   'model_2[0][0]']
#
#  model_3 (Functional)           (None, 48, 1)        169813      ['concatenate_8[0][0]']
#
# ==================================================================================================
# Total params: 174,389
# Trainable params: 174,389
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from sklearn.neighbors import KNeighborsRegressor
import numpy as np
from sklearn.model_selection import train_test_split
from netCDF4 import Dataset

with Dataset("simObsCrossTrack_2dn_extended.nc") as fh:
    yobsL=fh["tb"][:,:]
    x2D=fh["iwc_SSRG"][:,:]
    iwc_CS=fh["iwcCS"][:,:]
    zKu=fh["zKu"][:,:]
    pnorm=fh["pnorm"][:,:]
    pmol=fh["pmol"][:,:]

#set random seed
np.random.seed(42)
nt,nchan=yobsL.shape   
lidarNoise=np.random.randn(nt,50)*0.1
pnorm=np.log10(1e-3*(pnorm)*10**lidarNoise+1e-9)
pnorm[pnorm<-8.0]=-8.0
pnormMax=pnorm.max(axis=-1)
nt,nchan=yobsL.shape
lidarEchoPeak=[]
zKuGtL=[]
#print(zKu.shape)
#stop
zKu+=np.random.randn(nt,50)
zKu[zKu<8]=0
# do pca on zKu
from sklearn.decomposition import PCA
bscatter=pnorm[:,30:45]
for i,pnorm1 in enumerate(pnorm):
    lidarEchoPeak.append([np.argmax(pnorm1)*0.24,2*pnorm1.max()])
    z1=zKu[i]
    a=np.nonzero(z1>8)
    if len(a[0])>0:
        zKuGtL.append(z1)
    else:
        zKuGtL.append(z1)
yobsL+=np.random.randn(nt,nchan)*3
zKuGtL=np.array(zKuGtL)
yobsRadiomLidar=np.concatenate((yobsL,pnorm),axis=-1)
yobsRadiomLidarRadar=np.concatenate((yobsL,lidarEchoPeak,pnorm,zKuGtL),axis=-1)
ind_train,ind_test,y_train, y_test = train_test_split(range(nt), x2D[:].sum(axis=-1)*0.24, test_size=0.33, random_state=42)
nt,nc=yobsL.shape

X1_train=yobsRadiomLidarRadar[ind_train,:]
X1_test=yobsRadiomLidarRadar[ind_test,:]
iwc_train=x2D[ind_train,:]
iwp_train=iwc_train.sum(axis=-1)*0.24
iwc_test=x2D[ind_test,:]
iwp_test=iwc_test.sum(axis=-1)*0.24

# %%
import pickle
with open('kmeans_iwc.pklz','rb') as f:
    kmeans_iwc=pickle.load(f)["kmeans_iwc"]

iwcCS_train=iwc_CS[ind_train,:]
iwcCS_test=iwc_CS[ind_test,:]
iwc_float=iwcCS_train[:,:].data.astype(np.float16)
labels_=kmeans_iwc.predict(iwc_float)
print(X1_train.shape)
print(iwc_train.shape)
#print(iwc_train.mean(axis=0))
import matplotlib.pyplot as plt
plt.plot(iwc_train.mean(axis=0)[5:40],np.arange(5,40))
# import standard scaler
from sklearn.preprocessing import StandardScaler
scalerIWC = StandardScaler()
a=list(range(1,49))
#a.append(50)
scalerIWC.fit(iwc_train[:,a])
iwc_train_scaled=scalerIWC.transform(iwc_train[:,a])
iwc_test_scaled=scalerIWC.transform(iwc_test[:,a])
print(iwc_train_scaled.shape)
nC=18
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
# Out:
# (561647, 112)
# (561647, 50)
# (561647, 48)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X1_train)
X_train_scaled=scaler.transform(X1_train)
X_test_scaled=scaler.transform(X1_test)
print(iwc_test_scaled.mean(axis=0))
# Out:
# [-1.14205877e-04 -1.53822718e-03 -5.95065930e-04  1.23765038e-03
#   2.05823606e-03  1.73068779e-03  2.39066933e-03  3.68972819e-03
#   4.01031608e-03  3.08971997e-03  2.07587238e-03  9.47610423e-04
#   3.30118404e-04 -1.58012997e-04 -2.87824043e-04 -1.20895617e-03
#  -1.76469932e-03 -1.27825985e-03 -2.29055276e-04  7.78628830e-04
#   1.45192455e-03  8.81536465e-04 -1.48063148e-04 -5.41869871e-04
#   2.96037440e-04  1.33811691e-03  2.37335478e-03  2.75026285e-03
#   3.07744150e-03  3.99577816e-03  4.40489603e-03  3.50329333e-03
#   1.96614848e-03  2.32901260e-03  2.52553202e-03  2.19993766e-03
#   1.56987973e-03  4.30251510e-04 -2.98467466e-04 -8.86406192e-06
#   7.19659467e-04  1.37616413e-03  2.33321725e-03  2.56036268e-03
#   1.82880731e-03  1.38751850e-03  1.92091230e-03  3.16089009e-03]

# %%
itrain=0
if itrain==1:
    history = unetLidarRadiometer.fit(
        [X_train_scaled[:,10:58,np.newaxis],X_train_scaled[:,:10]],iwc_train_scaled[:,:],
        validation_data=([X_test_scaled[:,10:58,np.newaxis],X_test_scaled[:,:10]], iwc_test_scaled[:,:]),
        batch_size=128,
        epochs=10,
        verbose=1)
    unetLidarRadiometer.save("lidarRadiometerUnet.h5")
else:
    # load model
    unetLidarRadiometer=tf.keras.models.load_model("lidarRadiometerUnet.h5")

# %%
iwcLR_=unetLidarRadiometer.predict([X_test_scaled[:,10:58,np.newaxis],X_test_scaled[:,:10]])
# Out:
# 2023-05-11 10:39:08.475442: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8645/8645 [==============================] - 21s 2ms/step

# %%
print(iwcLR_.shape)
# Out:
# (276633, 48, 1)

# %%
import matplotlib.pyplot as plt
import matplotlib
iwcLR_=scalerIWC.inverse_transform(iwcLR_[:,:,0])
#iwcLR_=np.array(iwcLR_[:,:,0])
iwpLR_=np.sum(iwcLR_,axis=1)*0.24
iwp_test_=np.sum(iwc_test,axis=1)*0.24
xbins=np.logspace(1,4,50)
#plt.figure(figsize=(6,6))

# %%
import matplotlib
import matplotlib.pyplot as plt
ax=plt.subplot(111)
iwp_hist=plt.hist2d(iwp_test_*1000,iwpLR_*1000,bins=xbins,norm=matplotlib.colors.LogNorm(),cmap='jet')
plt.plot([0.1,1e4],[0.1,1e4],'k--')
truthL=[]
predictionL=[]
xbins=np.logspace(1,4,50)
for i in range(49):
    a=np.nonzero((iwp_test_*1000>xbins[i]) & (iwp_test_*1000<xbins[i+1]))
    if len(a[0])>0:
        truthL.append(1000*iwp_test_[a].mean())
        predictionL.append(1000*iwpLR_[a].mean())
plt.plot(truthL,predictionL,'k-',linewidth=3,label='Conditional mean')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.xlabel("True IWP (g/m$^2$)")
plt.ylabel("Retrieved IWP (g/m$^2$)")
plt.title('Lidar-Radiometer')
ax.set_aspect('equal')
plt.grid()
cbar=plt.colorbar(iwp_hist[-1])
cbar.set_label('Counts')
plt.savefig('lidarRadiometer_IWP.png')

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

nC=18 # number of clusters

iwc_class_=kmeans_iwc.predict(iwc_test)
plt.figure(figsize=(7,8))

iclass=0
cols=['b','orange','g']

iwcLR_=np.array(iwcLR_)
leg1=['True',None,None]
leg2=['Lidar-Radiometer Retr.',None,None]
iclass=0
for i in range(3):
    for j in range(2):
        ax=plt.subplot(3,2,i*2+j+1)
        if j>0:
            i1=1
            #ax.yaxis.set_visible(False)
            #ax.set_ylabel('')
        else:
            ax.set_ylabel('Rel. height (km)')
        if i==3:
            ax.set_xlabel('IWG [g/m3]')
        #ax.xaxis.set_visible(False)
        for k in range(3):
            a=np.nonzero(iwc_class_==iclass)[0]
            if len(a)>0:
                plt.plot((iwc_test[a,:45]).mean(axis=0),np.arange(0,45)*0.24,color=cols[k],label=leg1[k])
                plt.plot((iwcLR_[a,:45]).mean(axis=0),np.arange(0,45)*0.24,'*',color=cols[k],label=leg2[k])
                #plt.plot((iwcR_[a,:45]).mean(axis=0),np.arange(0,45)*0.24,'o',color=cols[k])
            # plot yticks no labels
                ax.set_yticks(np.arange(0,12.5,2.5))
                ax.grid()
            iclass+=1
        if i==2:
            ax.set_xlabel('IWG [g/m$^3$]')
        if i==0:
            plt.legend()
            #ax.set_ylabel('Rel. height (km)')
plt.suptitle('Conditional mean IWC')
plt.tight_layout()
plt.savefig('lidarRadiometerIWC_Prof.png')
def nrms(iwc1,iwc2):
    return np.sqrt(np.mean((iwc1.flatten()-iwc2.flatten())**2))/np.sqrt(np.mean(iwc1.flatten()**2))
print(nrms(iwc_test[:,1:49],iwcLR_))
def bias(iwc1,iwc2):
    return np.mean(-(iwc1.flatten()-iwc2.flatten())/iwc1.flatten())
print(bias(iwc_test[:,1:49],iwcLR_))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import matplotlib.pyplot as plt
#       4 nC=18 # number of clusters
# ----> 6 iwc_class_=kmeans_iwc.predict(iwc_test)
#       7 plt.figure(figsize=(7,8))
#       9 iclass=0
#
# NameError: name 'kmeans_iwc' is not defined

# %%
import matplotlib
hgRealL=[]
hgPredL=[]
#print(iwcL_.shape)
print(iwc_test.shape)
for i,iwc1 in enumerate(iwcLR_):
    #hc1=(iwc1*np.arange(50)).sum()*0.24/iwc1.sum()
    #hc2=(iwc_test[i,:]*np.arange(50)).sum()*0.24/iwc_test[i,:].sum()
    a1=np.nonzero(iwc1>0.0001)
    hc1=np.argmax(iwc1)*0.24
    hc2=np.argmax(iwc_test[i,:])*0.24
    h=np.arange(50)
    if len(a1[0])>2:
        hc1=(iwc1[a1]*h[a1]).sum()*0.24/iwc1[a1].sum()
        hc2=(iwc_test[i,:][a1]*h[a1]).sum()*0.24/iwc_test[i,a1[0]].sum()
    #print(hc1,hc2)
    if hc1>0 and hc2>0:
        hgRealL.append(hc2)
        hgPredL.append(hc1)
plt.figure()
ax=plt.subplot(111)
hist2d_=plt.hist2d(hgRealL,hgPredL,bins=20,cmap='jet',norm=matplotlib.colors.LogNorm())
ax.set_aspect('equal')
plt.grid()
plt.xlabel('True IWC gravity center height (km)')
plt.ylabel('Retrieved IWC gravity center height (km)')
plt.xlim(1,10)
plt.ylim(1,10)
cbar=plt.colorbar(hist2d_[-1])
plt.title('Lidar-Radiometer')
cbar.set_label('Counts')
plt.savefig('lidarRadiometer_GC.png')
print(np.corrcoef(hgRealL,hgPredL))
# Out:
# (276633, 50)
# /var/folders/x_/d2_jzyq50052xh1_tk02bnmc0000gq/T/ipykernel_21867/48444699.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   hc2=(iwc_test[i,:][a1]*h[a1]).sum()*0.24/iwc_test[i,a1[0]].sum()
# [[1.         0.66549626]
#  [0.66549626 1.        ]]

# %%
# Out:
# 0.5637460439352303
